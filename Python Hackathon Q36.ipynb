# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pip install qbstyles
# Out:
# Collecting qbstyles
#   Downloading qbstyles-0.1.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: matplotlib<4.0,>=3.0.3 in c:\users\anubh\anaconda3\lib\site-packages (from qbstyles) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\anubh\anaconda3\lib\site-packages (from matplotlib<4.0,>=3.0.3->qbstyles) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anubh\anaconda3\lib\site-packages (from matplotlib<4.0,>=3.0.3->qbstyles) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anubh\anaconda3\lib\site-packages (from matplotlib<4.0,>=3.0.3->qbstyles) (1.1.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\anubh\anaconda3\lib\site-packages (from matplotlib<4.0,>=3.0.3->qbstyles) (1.18.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\anubh\anaconda3\lib\site-packages (from matplotlib<4.0,>=3.0.3->qbstyles) (20.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anubh\anaconda3\lib\site-packages (from matplotlib<4.0,>=3.0.3->qbstyles) (7.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anubh\anaconda3\lib\site-packages (from matplotlib<4.0,>=3.0.3->qbstyles) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anubh\anaconda3\lib\site-packages (from matplotlib<4.0,>=3.0.3->qbstyles) (2.8.1)
# Requirement already satisfied: six in c:\users\anubh\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib<4.0,>=3.0.3->qbstyles) (1.14.0)
# Requirement already satisfied: setuptools in c:\users\anubh\anaconda3\lib\site-packages (from kiwisolver>=1.0.1->matplotlib<4.0,>=3.0.3->qbstyles) (45.2.0.post20200210)
# Downloading qbstyles-0.1.4-py3-none-any.whl (10 kB)
# Installing collected packages: qbstyles
# Successfully installed qbstyles-0.1.4
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %% [markdown]
# #Q36 : Use the QB style library to create any multidimensional arrays.Create a figure object called fig using plt.figure() **
# ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# ** Plot (x,y) on that axes and set the labels.

# %%
x = np.random.randint(1,25,size=(3,4))
y = np.sin(2 * x)
print(x)
print(y)
# Out:
# [[12 13 13 24]
#  [22 13  3  2]
#  [16 18 24 14]]
# [[-0.90557836  0.76255845  0.76255845 -0.76825466]
#  [ 0.01770193  0.76255845 -0.2794155  -0.7568025 ]
#  [ 0.55142668 -0.99177885 -0.76825466  0.27090579]]

# %%
from qbstyles import mpl_style
mpl_style(dark=True)
fig = plt.figure(figsize=(10,6))
ax = fig.add_axes([0,0,1,1], facecolor='0')
ax.plot(x,y,lw=3)
# Out:
# [<matplotlib.lines.Line2D at 0x18a4253df48>,
#  <matplotlib.lines.Line2D at 0x18a42550d48>,
#  <matplotlib.lines.Line2D at 0x18a42559e08>,
#  <matplotlib.lines.Line2D at 0x18a42564048>]
